# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 3
sample_id = 25
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 3:
# Samples: 10000
# Label Counts: {0: 994, 1: 1042, 2: 965, 3: 997, 4: 990, 5: 1029, 6: 978, 7: 1015, 8: 961, 9: 1029}
# First 20 Labels: [8, 5, 0, 6, 9, 2, 8, 3, 6, 2, 7, 4, 6, 9, 0, 0, 7, 3, 7, 2]
#
# Example of Image 25:
# Image - Min Value: 6 Max Value: 167
# Image - Shape: (32, 32, 3)
# Label - Label Id: 6 Name: frog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    norm_min = np.min(x)
    norm_max = np.max(x)
    return (x-norm_min)/(norm_max-norm_min)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    numpx = 10 ##np.max(x)+1
    return np.eye(numpx)[x]

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(
        tf.float32,[None, image_shape[0], image_shape[1],3], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(
        tf.float32,[None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name = 'keep_prob')
    ##note to self: If doesnt work change to keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    #Input channel
    input_depth = int(x_tensor.get_shape()[3])
    #Filter Weight
    weights = tf.Variable(tf.truncated_normal((conv_ksize[0],conv_ksize[1],input_depth,conv_num_outputs),mean=0.0, stddev=0.1,dtype=tf.float32))
    #Filter bias
    bias = tf.Variable(tf.zeros([conv_num_outputs]))
    #Init Convolutions
    convolution = tf.nn.conv2d(x_tensor, weights, strides=[1, conv_strides[0], conv_strides[1], 1], padding='SAME')   
    convolution = tf.nn.bias_add(convolution, bias)
    convolution = tf.nn.relu(convolution)
    convolution = tf.nn.max_pool(convolution,ksize=[1,pool_ksize[0],pool_ksize[1],1], strides=[1, pool_strides[0],pool_strides[1], 1], padding='SAME')
   
    return convolution 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    return tf.reshape(x_tensor,[-1, x_tensor.get_shape().as_list()[1] * x_tensor.get_shape().as_list()[2] * x_tensor.get_shape().as_list()[3]])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    layer_weights = tf.Variable(tf.truncated_normal((x_tensor.get_shape().as_list()[1],num_outputs),mean=0.0, stddev=0.01))    
    layer_biases = tf.Variable(tf.zeros([num_outputs]))

    return tf.nn.relu(tf.add(tf.matmul( x_tensor,layer_weights),layer_biases))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    print("Xtensor: ", x_tensor.get_shape()[-1])
    #view outputs
    print("num_outputs: ", num_outputs)
    output_weights = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[-1],num_outputs],mean=0.0, stddev=0.01))
    output_biases = tf.Variable(tf.zeros([num_outputs]))
    
    return tf.nn.bias_add(tf.matmul(x_tensor,output_weights),output_biases)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Xtensor:  128
# num_outputs:  40
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    layer = conv2d_maxpool(x, 16,(3,3),(1,1),(3,3),(2,2))
    #layer = conv2d_maxpool(layer, 32,(4,4),(1,1),(1,1),(1,1))
    #layer = conv2d_maxpool(layer, 64,(4,4),(1,1),(2,2),(2,2))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    layer = flatten(layer)


    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    layer = fully_conn(layer,50)
    layer = tf.nn.dropout(layer,keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    output_layer = output(layer,10)
    
    # TODO: return output
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Xtensor:  50
# num_outputs:  10
# Xtensor:  50
# num_outputs:  10
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, 
                feed_dict={
                    x: feature_batch, 
                    y: label_batch, 
                    keep_prob: keep_probability
                }
               )



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    print("Loss:", session.run(cost,feed_dict={x: feature_batch,y: label_batch,keep_prob: 1.0}))
    print("Train-Accu:", session.run(accuracy, feed_dict={x: feature_batch,y: label_batch,keep_prob: 1.0}))
    print("Valid-Accu:", session.run(accuracy, feed_dict={x: valid_features,y: valid_labels,keep_prob: 1.0}))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 56
batch_size = 560
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 2.23162
# Train-Accu: 0.2
# Valid-Accu: 0.2504
# Epoch  2, CIFAR-10 Batch 1:  Loss: 2.12337
# Train-Accu: 0.275
# Valid-Accu: 0.2548
# Epoch  3, CIFAR-10 Batch 1:  Loss: 2.08649
# Train-Accu: 0.3
# Valid-Accu: 0.2938
# Epoch  4, CIFAR-10 Batch 1:  Loss: 2.03966
# Train-Accu: 0.275
# Valid-Accu: 0.3192
# Epoch  5, CIFAR-10 Batch 1:  Loss: 1.9716
# Train-Accu: 0.375
# Valid-Accu: 0.3234
# Epoch  6, CIFAR-10 Batch 1:  Loss: 1.93037
# Train-Accu: 0.375
# Valid-Accu: 0.3316
# Epoch  7, CIFAR-10 Batch 1:  Loss: 1.88335
# Train-Accu: 0.425
# Valid-Accu: 0.3372
# Epoch  8, CIFAR-10 Batch 1:  Loss: 1.8427
# Train-Accu: 0.425
# Valid-Accu: 0.346
# Epoch  9, CIFAR-10 Batch 1:  Loss: 1.80627
# Train-Accu: 0.425
# Valid-Accu: 0.3574
# Epoch 10, CIFAR-10 Batch 1:  Loss: 1.76676
# Train-Accu: 0.425
# Valid-Accu: 0.3556
# Epoch 11, CIFAR-10 Batch 1:  Loss: 1.72243
# Train-Accu: 0.5
# Valid-Accu: 0.3678
# Epoch 12, CIFAR-10 Batch 1:  Loss: 1.68985
# Train-Accu: 0.5
# Valid-Accu: 0.367
# Epoch 13, CIFAR-10 Batch 1:  Loss: 1.65468
# Train-Accu: 0.5
# Valid-Accu: 0.3796
# Epoch 14, CIFAR-10 Batch 1:  Loss: 1.61408
# Train-Accu: 0.55
# Valid-Accu: 0.3906
# Epoch 15, CIFAR-10 Batch 1:  Loss: 1.58224
# Train-Accu: 0.525
# Valid-Accu: 0.3956
# Epoch 16, CIFAR-10 Batch 1:  Loss: 1.53731
# Train-Accu: 0.55
# Valid-Accu: 0.392
# Epoch 17, CIFAR-10 Batch 1:  Loss: 1.48721
# Train-Accu: 0.55
# Valid-Accu: 0.3954
# Epoch 18, CIFAR-10 Batch 1:  Loss: 1.45265
# Train-Accu: 0.6
# Valid-Accu: 0.4134
# Epoch 19, CIFAR-10 Batch 1:  Loss: 1.42878
# Train-Accu: 0.625
# Valid-Accu: 0.4166
# Epoch 20, CIFAR-10 Batch 1:  Loss: 1.35936
# Train-Accu: 0.575
# Valid-Accu: 0.4098
# Epoch 21, CIFAR-10 Batch 1:  Loss: 1.32826
# Train-Accu: 0.675
# Valid-Accu: 0.4216
# Epoch 22, CIFAR-10 Batch 1:  Loss: 1.31526
# Train-Accu: 0.65
# Valid-Accu: 0.435
# Epoch 23, CIFAR-10 Batch 1:  Loss: 1.26171
# Train-Accu: 0.675
# Valid-Accu: 0.436
# Epoch 24, CIFAR-10 Batch 1:  Loss: 1.23678
# Train-Accu: 0.675
# Valid-Accu: 0.44
# Epoch 25, CIFAR-10 Batch 1:  Loss: 1.22289
# Train-Accu: 0.7
# Valid-Accu: 0.4362
# Epoch 26, CIFAR-10 Batch 1:  Loss: 1.16682
# Train-Accu: 0.725
# Valid-Accu: 0.4562
# Epoch 27, CIFAR-10 Batch 1:  Loss: 1.13561
# Train-Accu: 0.7
# Valid-Accu: 0.4564
# Epoch 28, CIFAR-10 Batch 1:  Loss: 1.10525
# Train-Accu: 0.725
# Valid-Accu: 0.4524
# Epoch 29, CIFAR-10 Batch 1:  Loss: 1.09748
# Train-Accu: 0.775
# Valid-Accu: 0.449
# Epoch 30, CIFAR-10 Batch 1:  Loss: 1.05351
# Train-Accu: 0.775
# Valid-Accu: 0.467
# Epoch 31, CIFAR-10 Batch 1:  Loss: 1.026
# Train-Accu: 0.75
# Valid-Accu: 0.4656
# Epoch 32, CIFAR-10 Batch 1:  Loss: 0.997663
# Train-Accu: 0.825
# Valid-Accu: 0.4684
# Epoch 33, CIFAR-10 Batch 1:  Loss: 0.988425
# Train-Accu: 0.85
# Valid-Accu: 0.4544
# Epoch 34, CIFAR-10 Batch 1:  Loss: 0.941141
# Train-Accu: 0.85
# Valid-Accu: 0.4662
# Epoch 35, CIFAR-10 Batch 1:  Loss: 0.93757
# Train-Accu: 0.825
# Valid-Accu: 0.4654
# Epoch 36, CIFAR-10 Batch 1:  Loss: 0.910065
# Train-Accu: 0.8
# Valid-Accu: 0.473
# Epoch 37, CIFAR-10 Batch 1:  Loss: 0.867194
# Train-Accu: 0.85
# Valid-Accu: 0.4776
# Epoch 38, CIFAR-10 Batch 1:  Loss: 0.894185
# Train-Accu: 0.825
# Valid-Accu: 0.4776
# Epoch 39, CIFAR-10 Batch 1:  Loss: 0.8437
# Train-Accu: 0.85
# Valid-Accu: 0.4846
# Epoch 40, CIFAR-10 Batch 1:  Loss: 0.84295
# Train-Accu: 0.85
# Valid-Accu: 0.4782
# Epoch 41, CIFAR-10 Batch 1:  Loss: 0.828171
# Train-Accu: 0.85
# Valid-Accu: 0.4872
# Epoch 42, CIFAR-10 Batch 1:  Loss: 0.786815
# Train-Accu: 0.85
# Valid-Accu: 0.4912
# Epoch 43, CIFAR-10 Batch 1:  Loss: 0.779853
# Train-Accu: 0.875
# Valid-Accu: 0.4828
# Epoch 44, CIFAR-10 Batch 1:  Loss: 0.780278
# Train-Accu: 0.85
# Valid-Accu: 0.4768
# Epoch 45, CIFAR-10 Batch 1:  Loss: 0.760982
# Train-Accu: 0.875
# Valid-Accu: 0.4928
# Epoch 46, CIFAR-10 Batch 1:  Loss: 0.740055
# Train-Accu: 0.875
# Valid-Accu: 0.4906
# Epoch 47, CIFAR-10 Batch 1:  Loss: 0.722509
# Train-Accu: 0.875
# Valid-Accu: 0.4972
# Epoch 48, CIFAR-10 Batch 1:  Loss: 0.710801
# Train-Accu: 0.85
# Valid-Accu: 0.489
# Epoch 49, CIFAR-10 Batch 1:  Loss: 0.707074
# Train-Accu: 0.875
# Valid-Accu: 0.49
# Epoch 50, CIFAR-10 Batch 1:  Loss: 0.696785
# Train-Accu: 0.875
# Valid-Accu: 0.4904
# Epoch 51, CIFAR-10 Batch 1:  Loss: 0.697261
# Train-Accu: 0.875
# Valid-Accu: 0.489
# Epoch 52, CIFAR-10 Batch 1:  Loss: 0.650655
# Train-Accu: 0.875
# Valid-Accu: 0.5
# Epoch 53, CIFAR-10 Batch 1:  Loss: 0.643183
# Train-Accu: 0.875
# Valid-Accu: 0.4972
# Epoch 54, CIFAR-10 Batch 1:  Loss: 0.647788
# Train-Accu: 0.875
# Valid-Accu: 0.4912
# Epoch 55, CIFAR-10 Batch 1:  Loss: 0.624245
# Train-Accu: 0.875
# Valid-Accu: 0.4954
# Epoch 56, CIFAR-10 Batch 1:  Loss: 0.655224
# Train-Accu: 0.875
# Valid-Accu: 0.4984

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 2.2414
# Train-Accu: 0.175
# Valid-Accu: 0.1762
# Epoch  1, CIFAR-10 Batch 2:  Loss: 2.16014
# Train-Accu: 0.225
# Valid-Accu: 0.2138
# Epoch  1, CIFAR-10 Batch 3:  Loss: 1.88868
# Train-Accu: 0.325
# Valid-Accu: 0.251
# Epoch  1, CIFAR-10 Batch 4:  Loss: 1.99659
# Train-Accu: 0.225
# Valid-Accu: 0.2896
# Epoch  1, CIFAR-10 Batch 5:  Loss: 1.93276
# Train-Accu: 0.375
# Valid-Accu: 0.3228
# Epoch  2, CIFAR-10 Batch 1:  Loss: 2.0809
# Train-Accu: 0.225
# Valid-Accu: 0.308
# Epoch  2, CIFAR-10 Batch 2:  Loss: 1.92705
# Train-Accu: 0.35
# Valid-Accu: 0.3444
# Epoch  2, CIFAR-10 Batch 3:  Loss: 1.70026
# Train-Accu: 0.425
# Valid-Accu: 0.3456
# Epoch  2, CIFAR-10 Batch 4:  Loss: 1.75822
# Train-Accu: 0.325
# Valid-Accu: 0.358
# Epoch  2, CIFAR-10 Batch 5:  Loss: 1.75324
# Train-Accu: 0.475
# Valid-Accu: 0.3612
# Epoch  3, CIFAR-10 Batch 1:  Loss: 1.97651
# Train-Accu: 0.35
# Valid-Accu: 0.364
# Epoch  3, CIFAR-10 Batch 2:  Loss: 1.7977
# Train-Accu: 0.4
# Valid-Accu: 0.3764
# Epoch  3, CIFAR-10 Batch 3:  Loss: 1.61314
# Train-Accu: 0.525
# Valid-Accu: 0.3878
# Epoch  3, CIFAR-10 Batch 4:  Loss: 1.6924
# Train-Accu: 0.4
# Valid-Accu: 0.3806
# Epoch  3, CIFAR-10 Batch 5:  Loss: 1.65031
# Train-Accu: 0.4
# Valid-Accu: 0.4004
# Epoch  4, CIFAR-10 Batch 1:  Loss: 1.9077
# Train-Accu: 0.35
# Valid-Accu: 0.3918
# Epoch  4, CIFAR-10 Batch 2:  Loss: 1.69117
# Train-Accu: 0.4
# Valid-Accu: 0.397
# Epoch  4, CIFAR-10 Batch 3:  Loss: 1.527
# Train-Accu: 0.525
# Valid-Accu: 0.3986
# Epoch  4, CIFAR-10 Batch 4:  Loss: 1.60535
# Train-Accu: 0.375
# Valid-Accu: 0.4022
# Epoch  4, CIFAR-10 Batch 5:  Loss: 1.57493
# Train-Accu: 0.425
# Valid-Accu: 0.4062
# Epoch  5, CIFAR-10 Batch 1:  Loss: 1.84546
# Train-Accu: 0.4
# Valid-Accu: 0.4252
# Epoch  5, CIFAR-10 Batch 2:  Loss: 1.5933
# Train-Accu: 0.475
# Valid-Accu: 0.4128
# Epoch  5, CIFAR-10 Batch 3:  Loss: 1.45215
# Train-Accu: 0.575
# Valid-Accu: 0.4192
# Epoch  5, CIFAR-10 Batch 4:  Loss: 1.5649
# Train-Accu: 0.425
# Valid-Accu: 0.422
# Epoch  5, CIFAR-10 Batch 5:  Loss: 1.5251
# Train-Accu: 0.475
# Valid-Accu: 0.4214
# Epoch  6, CIFAR-10 Batch 1:  Loss: 1.77795
# Train-Accu: 0.45
# Valid-Accu: 0.4346
# Epoch  6, CIFAR-10 Batch 2:  Loss: 1.52772
# Train-Accu: 0.475
# Valid-Accu: 0.4332
# Epoch  6, CIFAR-10 Batch 3:  Loss: 1.36433
# Train-Accu: 0.6
# Valid-Accu: 0.443
# Epoch  6, CIFAR-10 Batch 4:  Loss: 1.50398
# Train-Accu: 0.4
# Valid-Accu: 0.4368
# Epoch  6, CIFAR-10 Batch 5:  Loss: 1.45477
# Train-Accu: 0.5
# Valid-Accu: 0.436
# Epoch  7, CIFAR-10 Batch 1:  Loss: 1.69357
# Train-Accu: 0.475
# Valid-Accu: 0.4488
# Epoch  7, CIFAR-10 Batch 2:  Loss: 1.44133
# Train-Accu: 0.5
# Valid-Accu: 0.4392
# Epoch  7, CIFAR-10 Batch 3:  Loss: 1.31748
# Train-Accu: 0.6
# Valid-Accu: 0.4538
# Epoch  7, CIFAR-10 Batch 4:  Loss: 1.47709
# Train-Accu: 0.475
# Valid-Accu: 0.4534
# Epoch  7, CIFAR-10 Batch 5:  Loss: 1.39978
# Train-Accu: 0.575
# Valid-Accu: 0.4494
# Epoch  8, CIFAR-10 Batch 1:  Loss: 1.63576
# Train-Accu: 0.475
# Valid-Accu: 0.4622
# Epoch  8, CIFAR-10 Batch 2:  Loss: 1.36556
# Train-Accu: 0.575
# Valid-Accu: 0.4656
# Epoch  8, CIFAR-10 Batch 3:  Loss: 1.22627
# Train-Accu: 0.6
# Valid-Accu: 0.4664
# Epoch  8, CIFAR-10 Batch 4:  Loss: 1.40875
# Train-Accu: 0.45
# Valid-Accu: 0.466
# Epoch  8, CIFAR-10 Batch 5:  Loss: 1.35294
# Train-Accu: 0.575
# Valid-Accu: 0.461
# Epoch  9, CIFAR-10 Batch 1:  Loss: 1.56952
# Train-Accu: 0.475
# Valid-Accu: 0.476
# Epoch  9, CIFAR-10 Batch 2:  Loss: 1.308
# Train-Accu: 0.575
# Valid-Accu: 0.4808
# Epoch  9, CIFAR-10 Batch 3:  Loss: 1.17426
# Train-Accu: 0.65
# Valid-Accu: 0.482
# Epoch  9, CIFAR-10 Batch 4:  Loss: 1.36737
# Train-Accu: 0.425
# Valid-Accu: 0.4814
# Epoch  9, CIFAR-10 Batch 5:  Loss: 1.2984
# Train-Accu: 0.625
# Valid-Accu: 0.4906
# Epoch 10, CIFAR-10 Batch 1:  Loss: 1.46107
# Train-Accu: 0.525
# Valid-Accu: 0.4926
# Epoch 10, CIFAR-10 Batch 2:  Loss: 1.23475
# Train-Accu: 0.6
# Valid-Accu: 0.494
# Epoch 10, CIFAR-10 Batch 3:  Loss: 1.1543
# Train-Accu: 0.65
# Valid-Accu: 0.4956
# Epoch 10, CIFAR-10 Batch 4:  Loss: 1.33832
# Train-Accu: 0.475
# Valid-Accu: 0.4956
# Epoch 10, CIFAR-10 Batch 5:  Loss: 1.23043
# Train-Accu: 0.65
# Valid-Accu: 0.4946
# Epoch 11, CIFAR-10 Batch 1:  Loss: 1.46483
# Train-Accu: 0.525
# Valid-Accu: 0.4952
# Epoch 11, CIFAR-10 Batch 2:  Loss: 1.21532
# Train-Accu: 0.6
# Valid-Accu: 0.499
# Epoch 11, CIFAR-10 Batch 3:  Loss: 1.10284
# Train-Accu: 0.7
# Valid-Accu: 0.5038
# Epoch 11, CIFAR-10 Batch 4:  Loss: 1.31557
# Train-Accu: 0.475
# Valid-Accu: 0.498
# Epoch 11, CIFAR-10 Batch 5:  Loss: 1.18844
# Train-Accu: 0.7
# Valid-Accu: 0.5026
# Epoch 12, CIFAR-10 Batch 1:  Loss: 1.38722
# Train-Accu: 0.6
# Valid-Accu: 0.5042
# Epoch 12, CIFAR-10 Batch 2:  Loss: 1.16285
# Train-Accu: 0.575
# Valid-Accu: 0.5128
# Epoch 12, CIFAR-10 Batch 3:  Loss: 1.04637
# Train-Accu: 0.7
# Valid-Accu: 0.519
# Epoch 12, CIFAR-10 Batch 4:  Loss: 1.26976
# Train-Accu: 0.475
# Valid-Accu: 0.51
# Epoch 12, CIFAR-10 Batch 5:  Loss: 1.18473
# Train-Accu: 0.75
# Valid-Accu: 0.5114
# Epoch 13, CIFAR-10 Batch 1:  Loss: 1.32096
# Train-Accu: 0.6
# Valid-Accu: 0.5156
# Epoch 13, CIFAR-10 Batch 2:  Loss: 1.11251
# Train-Accu: 0.65
# Valid-Accu: 0.5102
# Epoch 13, CIFAR-10 Batch 3:  Loss: 0.99541
# Train-Accu: 0.75
# Valid-Accu: 0.5158
# Epoch 13, CIFAR-10 Batch 4:  Loss: 1.23661
# Train-Accu: 0.475
# Valid-Accu: 0.5162
# Epoch 13, CIFAR-10 Batch 5:  Loss: 1.12243
# Train-Accu: 0.75
# Valid-Accu: 0.5206
# Epoch 14, CIFAR-10 Batch 1:  Loss: 1.2566
# Train-Accu: 0.575
# Valid-Accu: 0.5228
# Epoch 14, CIFAR-10 Batch 2:  Loss: 1.07589
# Train-Accu: 0.675
# Valid-Accu: 0.528
# Epoch 14, CIFAR-10 Batch 3:  Loss: 0.951674
# Train-Accu: 0.75
# Valid-Accu: 0.529
# Epoch 14, CIFAR-10 Batch 4:  Loss: 1.1771
# Train-Accu: 0.5
# Valid-Accu: 0.5314
# Epoch 14, CIFAR-10 Batch 5:  Loss: 1.09008
# Train-Accu: 0.775
# Valid-Accu: 0.5342
# Epoch 15, CIFAR-10 Batch 1:  Loss: 1.21078
# Train-Accu: 0.675
# Valid-Accu: 0.5284
# Epoch 15, CIFAR-10 Batch 2:  Loss: 1.04194
# Train-Accu: 0.675
# Valid-Accu: 0.5294
# Epoch 15, CIFAR-10 Batch 3:  Loss: 0.943624
# Train-Accu: 0.725
# Valid-Accu: 0.5356
# Epoch 15, CIFAR-10 Batch 4:  Loss: 1.13389
# Train-Accu: 0.5
# Valid-Accu: 0.5348
# Epoch 15, CIFAR-10 Batch 5:  Loss: 1.07987
# Train-Accu: 0.775
# Valid-Accu: 0.533
# Epoch 16, CIFAR-10 Batch 1:  Loss: 1.17353
# Train-Accu: 0.625
# Valid-Accu: 0.5342
# Epoch 16, CIFAR-10 Batch 2:  Loss: 0.993697
# Train-Accu: 0.675
# Valid-Accu: 0.5386
# Epoch 16, CIFAR-10 Batch 3:  Loss: 0.878567
# Train-Accu: 0.775
# Valid-Accu: 0.5398
# Epoch 16, CIFAR-10 Batch 4:  Loss: 1.11204
# Train-Accu: 0.525
# Valid-Accu: 0.5324
# Epoch 16, CIFAR-10 Batch 5:  Loss: 1.03722
# Train-Accu: 0.775
# Valid-Accu: 0.5394
# Epoch 17, CIFAR-10 Batch 1:  Loss: 1.14894
# Train-Accu: 0.675
# Valid-Accu: 0.5352
# Epoch 17, CIFAR-10 Batch 2:  Loss: 0.984025
# Train-Accu: 0.675
# Valid-Accu: 0.543
# Epoch 17, CIFAR-10 Batch 3:  Loss: 0.859985
# Train-Accu: 0.775
# Valid-Accu: 0.545
# Epoch 17, CIFAR-10 Batch 4:  Loss: 1.08175
# Train-Accu: 0.525
# Valid-Accu: 0.5346
# Epoch 17, CIFAR-10 Batch 5:  Loss: 0.992869
# Train-Accu: 0.725
# Valid-Accu: 0.548
# Epoch 18, CIFAR-10 Batch 1:  Loss: 1.08487
# Train-Accu: 0.675
# Valid-Accu: 0.5444
# Epoch 18, CIFAR-10 Batch 2:  Loss: 0.926809
# Train-Accu: 0.725
# Valid-Accu: 0.5498
# Epoch 18, CIFAR-10 Batch 3:  Loss: 0.843339
# Train-Accu: 0.75
# Valid-Accu: 0.5432
# Epoch 18, CIFAR-10 Batch 4:  Loss: 1.04161
# Train-Accu: 0.55
# Valid-Accu: 0.5452
# Epoch 18, CIFAR-10 Batch 5:  Loss: 0.966363
# Train-Accu: 0.8
# Valid-Accu: 0.547
# Epoch 19, CIFAR-10 Batch 1:  Loss: 1.05081
# Train-Accu: 0.675
# Valid-Accu: 0.5496
# Epoch 19, CIFAR-10 Batch 2:  Loss: 0.913996
# Train-Accu: 0.7
# Valid-Accu: 0.5436
# Epoch 19, CIFAR-10 Batch 3:  Loss: 0.822209
# Train-Accu: 0.775
# Valid-Accu: 0.55
# Epoch 19, CIFAR-10 Batch 4:  Loss: 1.01653
# Train-Accu: 0.575
# Valid-Accu: 0.5512
# Epoch 19, CIFAR-10 Batch 5:  Loss: 0.925694
# Train-Accu: 0.825
# Valid-Accu: 0.5562
# Epoch 20, CIFAR-10 Batch 1:  Loss: 1.02498
# Train-Accu: 0.675
# Valid-Accu: 0.5564
# Epoch 20, CIFAR-10 Batch 2:  Loss: 0.892
# Train-Accu: 0.725
# Valid-Accu: 0.5444
# Epoch 20, CIFAR-10 Batch 3:  Loss: 0.820493
# Train-Accu: 0.875
# Valid-Accu: 0.5538
# Epoch 20, CIFAR-10 Batch 4:  Loss: 0.9841
# Train-Accu: 0.6
# Valid-Accu: 0.5492
# Epoch 20, CIFAR-10 Batch 5:  Loss: 0.88508
# Train-Accu: 0.825
# Valid-Accu: 0.557
# Epoch 21, CIFAR-10 Batch 1:  Loss: 0.967943
# Train-Accu: 0.75
# Valid-Accu: 0.5628
# Epoch 21, CIFAR-10 Batch 2:  Loss: 0.874296
# Train-Accu: 0.725
# Valid-Accu: 0.5614
# Epoch 21, CIFAR-10 Batch 3:  Loss: 0.808595
# Train-Accu: 0.8
# Valid-Accu: 0.5622
# Epoch 21, CIFAR-10 Batch 4:  Loss: 0.938145
# Train-Accu: 0.65
# Valid-Accu: 0.5536
# Epoch 21, CIFAR-10 Batch 5:  Loss: 0.873532
# Train-Accu: 0.85
# Valid-Accu: 0.56
# Epoch 22, CIFAR-10 Batch 1:  Loss: 0.954757
# Train-Accu: 0.725
# Valid-Accu: 0.5552
# Epoch 22, CIFAR-10 Batch 2:  Loss: 0.824932
# Train-Accu: 0.775
# Valid-Accu: 0.5676
# Epoch 22, CIFAR-10 Batch 3:  Loss: 0.755194
# Train-Accu: 0.875
# Valid-Accu: 0.5624
# Epoch 22, CIFAR-10 Batch 4:  Loss: 0.941453
# Train-Accu: 0.625
# Valid-Accu: 0.5592
# Epoch 22, CIFAR-10 Batch 5:  Loss: 0.850063
# Train-Accu: 0.875
# Valid-Accu: 0.5614
# Epoch 23, CIFAR-10 Batch 1:  Loss: 0.909752
# Train-Accu: 0.775
# Valid-Accu: 0.5618
# Epoch 23, CIFAR-10 Batch 2:  Loss: 0.788622
# Train-Accu: 0.8
# Valid-Accu: 0.564
# Epoch 23, CIFAR-10 Batch 3:  Loss: 0.738118
# Train-Accu: 0.875
# Valid-Accu: 0.5666
# Epoch 23, CIFAR-10 Batch 4:  Loss: 0.903507
# Train-Accu: 0.7
# Valid-Accu: 0.5704
# Epoch 23, CIFAR-10 Batch 5:  Loss: 0.845701
# Train-Accu: 0.825
# Valid-Accu: 0.5582
# Epoch 24, CIFAR-10 Batch 1:  Loss: 0.902584
# Train-Accu: 0.775
# Valid-Accu: 0.567
# Epoch 24, CIFAR-10 Batch 2:  Loss: 0.790431
# Train-Accu: 0.775
# Valid-Accu: 0.5618
# Epoch 24, CIFAR-10 Batch 3:  Loss: 0.718812
# Train-Accu: 0.875
# Valid-Accu: 0.565
# Epoch 24, CIFAR-10 Batch 4:  Loss: 0.883958
# Train-Accu: 0.725
# Valid-Accu: 0.5646
# Epoch 24, CIFAR-10 Batch 5:  Loss: 0.822202
# Train-Accu: 0.9
# Valid-Accu: 0.57
# Epoch 25, CIFAR-10 Batch 1:  Loss: 0.876531
# Train-Accu: 0.775
# Valid-Accu: 0.5618
# Epoch 25, CIFAR-10 Batch 2:  Loss: 0.760544
# Train-Accu: 0.75
# Valid-Accu: 0.5698
# Epoch 25, CIFAR-10 Batch 3:  Loss: 0.701819
# Train-Accu: 0.9
# Valid-Accu: 0.5682
# Epoch 25, CIFAR-10 Batch 4:  Loss: 0.866935
# Train-Accu: 0.75
# Valid-Accu: 0.5626
# Epoch 25, CIFAR-10 Batch 5:  Loss: 0.777609
# Train-Accu: 0.875
# Valid-Accu: 0.562
# Epoch 26, CIFAR-10 Batch 1:  Loss: 0.875037
# Train-Accu: 0.775
# Valid-Accu: 0.5586
# Epoch 26, CIFAR-10 Batch 2:  Loss: 0.753256
# Train-Accu: 0.75
# Valid-Accu: 0.577
# Epoch 26, CIFAR-10 Batch 3:  Loss: 0.687452
# Train-Accu: 0.85
# Valid-Accu: 0.5676
# Epoch 26, CIFAR-10 Batch 4:  Loss: 0.834356
# Train-Accu: 0.725
# Valid-Accu: 0.5678
# Epoch 26, CIFAR-10 Batch 5:  Loss: 0.797333
# Train-Accu: 0.875
# Valid-Accu: 0.5566
# Epoch 27, CIFAR-10 Batch 1:  Loss: 0.854916
# Train-Accu: 0.825
# Valid-Accu: 0.5614
# Epoch 27, CIFAR-10 Batch 2:  Loss: 0.710243
# Train-Accu: 0.825
# Valid-Accu: 0.5692
# Epoch 27, CIFAR-10 Batch 3:  Loss: 0.672118
# Train-Accu: 0.925
# Valid-Accu: 0.572
# Epoch 27, CIFAR-10 Batch 4:  Loss: 0.822987
# Train-Accu: 0.725
# Valid-Accu: 0.5694
# Epoch 27, CIFAR-10 Batch 5:  Loss: 0.756296
# Train-Accu: 0.875
# Valid-Accu: 0.5696
# Epoch 28, CIFAR-10 Batch 1:  Loss: 0.817412
# Train-Accu: 0.75
# Valid-Accu: 0.5754
# Epoch 28, CIFAR-10 Batch 2:  Loss: 0.689605
# Train-Accu: 0.85
# Valid-Accu: 0.5686
# Epoch 28, CIFAR-10 Batch 3:  Loss: 0.627181
# Train-Accu: 0.925
# Valid-Accu: 0.5736
# Epoch 28, CIFAR-10 Batch 4:  Loss: 0.8009
# Train-Accu: 0.725
# Valid-Accu: 0.5762
# Epoch 28, CIFAR-10 Batch 5:  Loss: 0.729951
# Train-Accu: 0.9
# Valid-Accu: 0.5726
# Epoch 29, CIFAR-10 Batch 1:  Loss: 0.804088
# Train-Accu: 0.85
# Valid-Accu: 0.5674
# Epoch 29, CIFAR-10 Batch 2:  Loss: 0.665643
# Train-Accu: 0.825
# Valid-Accu: 0.5754
# Epoch 29, CIFAR-10 Batch 3:  Loss: 0.606701
# Train-Accu: 0.9
# Valid-Accu: 0.5804
# Epoch 29, CIFAR-10 Batch 4:  Loss: 0.769494
# Train-Accu: 0.75
# Valid-Accu: 0.5704
# Epoch 29, CIFAR-10 Batch 5:  Loss: 0.711566
# Train-Accu: 0.875
# Valid-Accu: 0.574
# Epoch 30, CIFAR-10 Batch 1:  Loss: 0.747408
# Train-Accu: 0.8
# Valid-Accu: 0.5786
# Epoch 30, CIFAR-10 Batch 2:  Loss: 0.664147
# Train-Accu: 0.825
# Valid-Accu: 0.576
# Epoch 30, CIFAR-10 Batch 3:  Loss: 0.603923
# Train-Accu: 0.925
# Valid-Accu: 0.5742
# Epoch 30, CIFAR-10 Batch 4:  Loss: 0.753875
# Train-Accu: 0.75
# Valid-Accu: 0.578
# Epoch 30, CIFAR-10 Batch 5:  Loss: 0.71368
# Train-Accu: 0.85
# Valid-Accu: 0.5664
# Epoch 31, CIFAR-10 Batch 1:  Loss: 0.768134
# Train-Accu: 0.825
# Valid-Accu: 0.576
# Epoch 31, CIFAR-10 Batch 2:  Loss: 0.65425
# Train-Accu: 0.825
# Valid-Accu: 0.5754
# Epoch 31, CIFAR-10 Batch 3:  Loss: 0.604449
# Train-Accu: 0.925
# Valid-Accu: 0.572
# Epoch 31, CIFAR-10 Batch 4:  Loss: 0.744184
# Train-Accu: 0.75
# Valid-Accu: 0.579
# Epoch 31, CIFAR-10 Batch 5:  Loss: 0.709394
# Train-Accu: 0.9
# Valid-Accu: 0.5782
# Epoch 32, CIFAR-10 Batch 1:  Loss: 0.749485
# Train-Accu: 0.8
# Valid-Accu: 0.5754
# Epoch 32, CIFAR-10 Batch 2:  Loss: 0.636679
# Train-Accu: 0.825
# Valid-Accu: 0.587
# Epoch 32, CIFAR-10 Batch 3:  Loss: 0.586074
# Train-Accu: 0.925
# Valid-Accu: 0.5826
# Epoch 32, CIFAR-10 Batch 4:  Loss: 0.710895
# Train-Accu: 0.775
# Valid-Accu: 0.5776
# Epoch 32, CIFAR-10 Batch 5:  Loss: 0.687308
# Train-Accu: 0.9
# Valid-Accu: 0.5834
# Epoch 33, CIFAR-10 Batch 1:  Loss: 0.705859
# Train-Accu: 0.825
# Valid-Accu: 0.5836
# Epoch 33, CIFAR-10 Batch 2:  Loss: 0.599085
# Train-Accu: 0.85
# Valid-Accu: 0.5834
# Epoch 33, CIFAR-10 Batch 3:  Loss: 0.55314
# Train-Accu: 0.875
# Valid-Accu: 0.577
# Epoch 33, CIFAR-10 Batch 4:  Loss: 0.693231
# Train-Accu: 0.75
# Valid-Accu: 0.5814
# Epoch 33, CIFAR-10 Batch 5:  Loss: 0.65794
# Train-Accu: 0.9
# Valid-Accu: 0.5782
# Epoch 34, CIFAR-10 Batch 1:  Loss: 0.711053
# Train-Accu: 0.825
# Valid-Accu: 0.5868
# Epoch 34, CIFAR-10 Batch 2:  Loss: 0.586775
# Train-Accu: 0.8
# Valid-Accu: 0.5796
# Epoch 34, CIFAR-10 Batch 3:  Loss: 0.559027
# Train-Accu: 0.9
# Valid-Accu: 0.582
# Epoch 34, CIFAR-10 Batch 4:  Loss: 0.689281
# Train-Accu: 0.825
# Valid-Accu: 0.584
# Epoch 34, CIFAR-10 Batch 5:  Loss: 0.635247
# Train-Accu: 0.9
# Valid-Accu: 0.5832
# Epoch 35, CIFAR-10 Batch 1:  Loss: 0.722208
# Train-Accu: 0.85
# Valid-Accu: 0.579
# Epoch 35, CIFAR-10 Batch 2:  Loss: 0.589295
# Train-Accu: 0.85
# Valid-Accu: 0.5868
# Epoch 35, CIFAR-10 Batch 3:  Loss: 0.541039
# Train-Accu: 0.925
# Valid-Accu: 0.5898
# Epoch 35, CIFAR-10 Batch 4:  Loss: 0.663325
# Train-Accu: 0.775
# Valid-Accu: 0.5772
# Epoch 35, CIFAR-10 Batch 5:  Loss: 0.629799
# Train-Accu: 0.9
# Valid-Accu: 0.583
# Epoch 36, CIFAR-10 Batch 1:  Loss: 0.683874
# Train-Accu: 0.875
# Valid-Accu: 0.5838
# Epoch 36, CIFAR-10 Batch 2:  Loss: 0.603763
# Train-Accu: 0.825
# Valid-Accu: 0.5916
# Epoch 36, CIFAR-10 Batch 3:  Loss: 0.543354
# Train-Accu: 0.925
# Valid-Accu: 0.5898
# Epoch 36, CIFAR-10 Batch 4:  Loss: 0.651783
# Train-Accu: 0.8
# Valid-Accu: 0.5806
# Epoch 36, CIFAR-10 Batch 5:  Loss: 0.623205
# Train-Accu: 0.9
# Valid-Accu: 0.5848
# Epoch 37, CIFAR-10 Batch 1:  Loss: 0.661867
# Train-Accu: 0.85
# Valid-Accu: 0.5908
# Epoch 37, CIFAR-10 Batch 2:  Loss: 0.586872
# Train-Accu: 0.875
# Valid-Accu: 0.5858
# Epoch 37, CIFAR-10 Batch 3:  Loss: 0.519168
# Train-Accu: 0.9
# Valid-Accu: 0.592
# Epoch 37, CIFAR-10 Batch 4:  Loss: 0.636109
# Train-Accu: 0.825
# Valid-Accu: 0.582
# Epoch 37, CIFAR-10 Batch 5:  Loss: 0.594126
# Train-Accu: 0.9
# Valid-Accu: 0.583
# Epoch 38, CIFAR-10 Batch 1:  Loss: 0.642014
# Train-Accu: 0.85
# Valid-Accu: 0.587
# Epoch 38, CIFAR-10 Batch 2:  Loss: 0.566985
# Train-Accu: 0.85
# Valid-Accu: 0.5906
# Epoch 38, CIFAR-10 Batch 3:  Loss: 0.512426
# Train-Accu: 0.95
# Valid-Accu: 0.5876
# Epoch 38, CIFAR-10 Batch 4:  Loss: 0.638236
# Train-Accu: 0.85
# Valid-Accu: 0.5934
# Epoch 38, CIFAR-10 Batch 5:  Loss: 0.590743
# Train-Accu: 0.925
# Valid-Accu: 0.5868
# Epoch 39, CIFAR-10 Batch 1:  Loss: 0.642043
# Train-Accu: 0.875
# Valid-Accu: 0.589
# Epoch 39, CIFAR-10 Batch 2:  Loss: 0.560979
# Train-Accu: 0.875
# Valid-Accu: 0.5882
# Epoch 39, CIFAR-10 Batch 3:  Loss: 0.50083
# Train-Accu: 0.95
# Valid-Accu: 0.5892
# Epoch 39, CIFAR-10 Batch 4:  Loss: 0.61671
# Train-Accu: 0.825
# Valid-Accu: 0.596
# Epoch 39, CIFAR-10 Batch 5:  Loss: 0.568353
# Train-Accu: 0.925
# Valid-Accu: 0.5928
# Epoch 40, CIFAR-10 Batch 1:  Loss: 0.638418
# Train-Accu: 0.9
# Valid-Accu: 0.5918
# Epoch 40, CIFAR-10 Batch 2:  Loss: 0.542061
# Train-Accu: 0.85
# Valid-Accu: 0.593
# Epoch 40, CIFAR-10 Batch 3:  Loss: 0.48026
# Train-Accu: 0.95
# Valid-Accu: 0.5962
# Epoch 40, CIFAR-10 Batch 4:  Loss: 0.601541
# Train-Accu: 0.9
# Valid-Accu: 0.592
# Epoch 40, CIFAR-10 Batch 5:  Loss: 0.57184
# Train-Accu: 0.95
# Valid-Accu: 0.587
# Epoch 41, CIFAR-10 Batch 1:  Loss: 0.602975
# Train-Accu: 0.9
# Valid-Accu: 0.5956
# Epoch 41, CIFAR-10 Batch 2:  Loss: 0.534551
# Train-Accu: 0.9
# Valid-Accu: 0.5878
# Epoch 41, CIFAR-10 Batch 3:  Loss: 0.474079
# Train-Accu: 0.95
# Valid-Accu: 0.5956
# Epoch 41, CIFAR-10 Batch 4:  Loss: 0.569132
# Train-Accu: 0.875
# Valid-Accu: 0.588
# Epoch 41, CIFAR-10 Batch 5:  Loss: 0.552705
# Train-Accu: 0.95
# Valid-Accu: 0.5948
# Epoch 42, CIFAR-10 Batch 1:  Loss: 0.621454
# Train-Accu: 0.875
# Valid-Accu: 0.5952
# Epoch 42, CIFAR-10 Batch 2:  Loss: 0.529494
# Train-Accu: 0.85
# Valid-Accu: 0.5942
# Epoch 42, CIFAR-10 Batch 3:  Loss: 0.482417
# Train-Accu: 0.975
# Valid-Accu: 0.5922
# Epoch 42, CIFAR-10 Batch 4:  Loss: 0.563638
# Train-Accu: 0.9
# Valid-Accu: 0.5952
# Epoch 42, CIFAR-10 Batch 5:  Loss: 0.511697
# Train-Accu: 0.95
# Valid-Accu: 0.5966
# Epoch 43, CIFAR-10 Batch 1:  Loss: 0.587184
# Train-Accu: 0.9
# Valid-Accu: 0.5956
# Epoch 43, CIFAR-10 Batch 2:  Loss: 0.524251
# Train-Accu: 0.85
# Valid-Accu: 0.5976
# Epoch 43, CIFAR-10 Batch 3:  Loss: 0.473584
# Train-Accu: 0.95
# Valid-Accu: 0.595
# Epoch 43, CIFAR-10 Batch 4:  Loss: 0.560163
# Train-Accu: 0.875
# Valid-Accu: 0.5896
# Epoch 43, CIFAR-10 Batch 5:  Loss: 0.51445
# Train-Accu: 0.925
# Valid-Accu: 0.5974
# Epoch 44, CIFAR-10 Batch 1:  Loss: 0.615745
# Train-Accu: 0.825
# Valid-Accu: 0.596
# Epoch 44, CIFAR-10 Batch 2:  Loss: 0.491878
# Train-Accu: 0.875
# Valid-Accu: 0.5896
# Epoch 44, CIFAR-10 Batch 3:  Loss: 0.441791
# Train-Accu: 0.925
# Valid-Accu: 0.5974
# Epoch 44, CIFAR-10 Batch 4:  Loss: 0.551917
# Train-Accu: 0.9
# Valid-Accu: 0.5962
# Epoch 44, CIFAR-10 Batch 5:  Loss: 0.528916
# Train-Accu: 0.95
# Valid-Accu: 0.596
# Epoch 45, CIFAR-10 Batch 1:  Loss: 0.612568
# Train-Accu: 0.9
# Valid-Accu: 0.597
# Epoch 45, CIFAR-10 Batch 2:  Loss: 0.498685
# Train-Accu: 0.85
# Valid-Accu: 0.591
# Epoch 45, CIFAR-10 Batch 3:  Loss: 0.441042
# Train-Accu: 0.95
# Valid-Accu: 0.6012
# Epoch 45, CIFAR-10 Batch 4:  Loss: 0.553629
# Train-Accu: 0.925
# Valid-Accu: 0.6008
# Epoch 45, CIFAR-10 Batch 5:  Loss: 0.526312
# Train-Accu: 0.975
# Valid-Accu: 0.5976
# Epoch 46, CIFAR-10 Batch 1:  Loss: 0.589786
# Train-Accu: 0.875
# Valid-Accu: 0.5974
# Epoch 46, CIFAR-10 Batch 2:  Loss: 0.480899
# Train-Accu: 0.85
# Valid-Accu: 0.5964
# Epoch 46, CIFAR-10 Batch 3:  Loss: 0.440438
# Train-Accu: 0.95
# Valid-Accu: 0.5976
# Epoch 46, CIFAR-10 Batch 4:  Loss: 0.541267
# Train-Accu: 0.975
# Valid-Accu: 0.603
# Epoch 46, CIFAR-10 Batch 5:  Loss: 0.499055
# Train-Accu: 0.95
# Valid-Accu: 0.6038
# Epoch 47, CIFAR-10 Batch 1:  Loss: 0.591353
# Train-Accu: 0.875
# Valid-Accu: 0.5988
# Epoch 47, CIFAR-10 Batch 2:  Loss: 0.504512
# Train-Accu: 0.85
# Valid-Accu: 0.5886
# Epoch 47, CIFAR-10 Batch 3:  Loss: 0.434251
# Train-Accu: 0.975
# Valid-Accu: 0.592
# Epoch 47, CIFAR-10 Batch 4:  Loss: 0.550978
# Train-Accu: 0.95
# Valid-Accu: 0.6018
# Epoch 47, CIFAR-10 Batch 5:  Loss: 0.503781
# Train-Accu: 0.95
# Valid-Accu: 0.6004
# Epoch 48, CIFAR-10 Batch 1:  Loss: 0.588005
# Train-Accu: 0.9
# Valid-Accu: 0.5962
# Epoch 48, CIFAR-10 Batch 2:  Loss: 0.468977
# Train-Accu: 0.875
# Valid-Accu: 0.6008
# Epoch 48, CIFAR-10 Batch 3:  Loss: 0.42515
# Train-Accu: 0.95
# Valid-Accu: 0.6032
# Epoch 48, CIFAR-10 Batch 4:  Loss: 0.531903
# Train-Accu: 0.9
# Valid-Accu: 0.5958
# Epoch 48, CIFAR-10 Batch 5:  Loss: 0.497942
# Train-Accu: 0.975
# Valid-Accu: 0.6024
# Epoch 49, CIFAR-10 Batch 1:  Loss: 0.545804
# Train-Accu: 0.9
# Valid-Accu: 0.608
# Epoch 49, CIFAR-10 Batch 2:  Loss: 0.463915
# Train-Accu: 0.9
# Valid-Accu: 0.5942
# Epoch 49, CIFAR-10 Batch 3:  Loss: 0.412648
# Train-Accu: 0.95
# Valid-Accu: 0.6056
# Epoch 49, CIFAR-10 Batch 4:  Loss: 0.513237
# Train-Accu: 0.925
# Valid-Accu: 0.5964
# Epoch 49, CIFAR-10 Batch 5:  Loss: 0.486589
# Train-Accu: 0.95
# Valid-Accu: 0.6072
# Epoch 50, CIFAR-10 Batch 1:  Loss: 0.542711
# Train-Accu: 0.9
# Valid-Accu: 0.6068
# Epoch 50, CIFAR-10 Batch 2:  Loss: 0.440396
# Train-Accu: 0.85
# Valid-Accu: 0.6074
# Epoch 50, CIFAR-10 Batch 3:  Loss: 0.421037
# Train-Accu: 0.975
# Valid-Accu: 0.6054
# Epoch 50, CIFAR-10 Batch 4:  Loss: 0.510028
# Train-Accu: 0.925
# Valid-Accu: 0.6014
# Epoch 50, CIFAR-10 Batch 5:  Loss: 0.476537
# Train-Accu: 0.95
# Valid-Accu: 0.6008
# Epoch 51, CIFAR-10 Batch 1:  Loss: 0.545881
# Train-Accu: 0.925
# Valid-Accu: 0.6102
# Epoch 51, CIFAR-10 Batch 2:  Loss: 0.450201
# Train-Accu: 0.875
# Valid-Accu: 0.6048
# Epoch 51, CIFAR-10 Batch 3:  Loss: 0.415162
# Train-Accu: 0.975
# Valid-Accu: 0.6078
# Epoch 51, CIFAR-10 Batch 4:  Loss: 0.493182
# Train-Accu: 0.925
# Valid-Accu: 0.6022
# Epoch 51, CIFAR-10 Batch 5:  Loss: 0.468309
# Train-Accu: 0.95
# Valid-Accu: 0.6014
# Epoch 52, CIFAR-10 Batch 1:  Loss: 0.529621
# Train-Accu: 0.925
# Valid-Accu: 0.6064
# Epoch 52, CIFAR-10 Batch 2:  Loss: 0.456945
# Train-Accu: 0.9
# Valid-Accu: 0.5956
# Epoch 52, CIFAR-10 Batch 3:  Loss: 0.411179
# Train-Accu: 1.0
# Valid-Accu: 0.604
# Epoch 52, CIFAR-10 Batch 4:  Loss: 0.488614
# Train-Accu: 0.975
# Valid-Accu: 0.6036
# Epoch 52, CIFAR-10 Batch 5:  Loss: 0.449488
# Train-Accu: 0.95
# Valid-Accu: 0.6066
# Epoch 53, CIFAR-10 Batch 1:  Loss: 0.530664
# Train-Accu: 0.9
# Valid-Accu: 0.6048
# Epoch 53, CIFAR-10 Batch 2:  Loss: 0.440197
# Train-Accu: 0.9
# Valid-Accu: 0.6048
# Epoch 53, CIFAR-10 Batch 3:  Loss: 0.412063
# Train-Accu: 0.975
# Valid-Accu: 0.606
# Epoch 53, CIFAR-10 Batch 4:  Loss: 0.483852
# Train-Accu: 0.95
# Valid-Accu: 0.5996
# Epoch 53, CIFAR-10 Batch 5:  Loss: 0.437981
# Train-Accu: 0.95
# Valid-Accu: 0.6076
# Epoch 54, CIFAR-10 Batch 1:  Loss: 0.523779
# Train-Accu: 0.95
# Valid-Accu: 0.6092
# Epoch 54, CIFAR-10 Batch 2:  Loss: 0.429002
# Train-Accu: 0.9
# Valid-Accu: 0.599
# Epoch 54, CIFAR-10 Batch 3:  Loss: 0.401684
# Train-Accu: 1.0
# Valid-Accu: 0.6098
# Epoch 54, CIFAR-10 Batch 4:  Loss: 0.492488
# Train-Accu: 0.925
# Valid-Accu: 0.5976
# Epoch 54, CIFAR-10 Batch 5:  Loss: 0.423831
# Train-Accu: 0.95
# Valid-Accu: 0.6088
# Epoch 55, CIFAR-10 Batch 1:  Loss: 0.51148
# Train-Accu: 0.95
# Valid-Accu: 0.6118
# Epoch 55, CIFAR-10 Batch 2:  Loss: 0.417175
# Train-Accu: 0.9
# Valid-Accu: 0.6094
# Epoch 55, CIFAR-10 Batch 3:  Loss: 0.405249
# Train-Accu: 0.95
# Valid-Accu: 0.6092
# Epoch 55, CIFAR-10 Batch 4:  Loss: 0.469845
# Train-Accu: 0.95
# Valid-Accu: 0.6034
# Epoch 55, CIFAR-10 Batch 5:  Loss: 0.441576
# Train-Accu: 0.95
# Valid-Accu: 0.6096
# Epoch 56, CIFAR-10 Batch 1:  Loss: 0.512632
# Train-Accu: 0.95
# Valid-Accu: 0.6102
# Epoch 56, CIFAR-10 Batch 2:  Loss: 0.422312
# Train-Accu: 0.9
# Valid-Accu: 0.6078
# Epoch 56, CIFAR-10 Batch 3:  Loss: 0.398724
# Train-Accu: 0.975
# Valid-Accu: 0.6086
# Epoch 56, CIFAR-10 Batch 4:  Loss: 0.463667
# Train-Accu: 0.975
# Valid-Accu: 0.6088
# Epoch 56, CIFAR-10 Batch 5:  Loss: 0.433466
# Train-Accu: 0.975
# Valid-Accu: 0.6132

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6214947369363573

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
